# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.tree import plot_tree

# %%
pd.read_csv("Raw_Data/Churn_Data.csv")
# Out:
#      state  account length  area code phone number international plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# ...    ...             ...        ...          ...                ...
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# 0                yes                     25              265.1
# 1                yes                     26              161.6
# 2                 no                      0              243.4
# 3                 no                      0              299.4
# 4                 no                      0              166.7
# ...              ...                    ...                ...
# 3328             yes                     36              156.2
# 3329              no                      0              231.1
# 3330              no                      0              180.8
# 3331              no                      0              213.8
# 3332             yes                     25              234.4
#
#       total day calls  total day charge  ...  total eve calls  \
# 0                 110             45.07  ...               99
# 1                 123             27.47  ...              103
# 2                 114             41.38  ...              110
# 3                  71             50.90  ...               88
# 4                 113             28.34  ...              122
# ...               ...               ...  ...              ...
# 3328               77             26.55  ...              126
# 3329               57             39.29  ...               55
# 3330              109             30.74  ...               58
# 3331              105             36.35  ...               84
# 3332              113             39.85  ...               82
#
#       total eve charge  total night minutes  total night calls  \
# 0                16.78                244.7                 91
# 1                16.62                254.4                103
# 2                10.30                162.6                104
# 3                 5.26                196.9                 89
# 4                12.61                186.9                121
# ...                ...                  ...                ...
# 3328             18.32                279.1                 83
# 3329             13.04                191.3                123
# 3330             24.55                191.9                 91
# 3331             13.57                139.2                137
# 3332             22.60                241.4                 77
#
#       total night charge  total intl minutes  total intl calls  \
# 0                  11.01                10.0                 3
# 1                  11.45                13.7                 3
# 2                   7.32                12.2                 5
# 3                   8.86                 6.6                 7
# 4                   8.41                10.1                 3
# ...                  ...                 ...               ...
# 3328               12.56                 9.9                 6
# 3329                8.61                 9.6                 4
# 3330                8.64                14.1                 6
# 3331                6.26                 5.0                10
# 3332               10.86                13.7                 4
#
#       total intl charge  customer service calls  churn
# 0                  2.70                       1  False
# 1                  3.70                       1  False
# 2                  3.29                       0  False
# 3                  1.78                       2  False
# 4                  2.73                       3  False
# ...                 ...                     ...    ...
# 3328               2.67                       2  False
# 3329               2.59                       3  False
# 3330               3.81                       2  False
# 3331               1.35                       2  False
# 3332               3.70                       0  False
#
# [3333 rows x 21 columns]

# %% [markdown]
# # Load the dataset into a Pandas DataFrame:

# %%
data = pd.read_csv("Raw_Data/Churn_Data.csv")

# %%
data
# Out:
#      state  account length  area code phone number international plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# ...    ...             ...        ...          ...                ...
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# 0                yes                     25              265.1
# 1                yes                     26              161.6
# 2                 no                      0              243.4
# 3                 no                      0              299.4
# 4                 no                      0              166.7
# ...              ...                    ...                ...
# 3328             yes                     36              156.2
# 3329              no                      0              231.1
# 3330              no                      0              180.8
# 3331              no                      0              213.8
# 3332             yes                     25              234.4
#
#       total day calls  total day charge  ...  total eve calls  \
# 0                 110             45.07  ...               99
# 1                 123             27.47  ...              103
# 2                 114             41.38  ...              110
# 3                  71             50.90  ...               88
# 4                 113             28.34  ...              122
# ...               ...               ...  ...              ...
# 3328               77             26.55  ...              126
# 3329               57             39.29  ...               55
# 3330              109             30.74  ...               58
# 3331              105             36.35  ...               84
# 3332              113             39.85  ...               82
#
#       total eve charge  total night minutes  total night calls  \
# 0                16.78                244.7                 91
# 1                16.62                254.4                103
# 2                10.30                162.6                104
# 3                 5.26                196.9                 89
# 4                12.61                186.9                121
# ...                ...                  ...                ...
# 3328             18.32                279.1                 83
# 3329             13.04                191.3                123
# 3330             24.55                191.9                 91
# 3331             13.57                139.2                137
# 3332             22.60                241.4                 77
#
#       total night charge  total intl minutes  total intl calls  \
# 0                  11.01                10.0                 3
# 1                  11.45                13.7                 3
# 2                   7.32                12.2                 5
# 3                   8.86                 6.6                 7
# 4                   8.41                10.1                 3
# ...                  ...                 ...               ...
# 3328               12.56                 9.9                 6
# 3329                8.61                 9.6                 4
# 3330                8.64                14.1                 6
# 3331                6.26                 5.0                10
# 3332               10.86                13.7                 4
#
#       total intl charge  customer service calls  churn
# 0                  2.70                       1  False
# 1                  3.70                       1  False
# 2                  3.29                       0  False
# 3                  1.78                       2  False
# 4                  2.73                       3  False
# ...                 ...                     ...    ...
# 3328               2.67                       2  False
# 3329               2.59                       3  False
# 3330               3.81                       2  False
# 3331               1.35                       2  False
# 3332               3.70                       0  False
#
# [3333 rows x 21 columns]

# %% [markdown]
# # Define the features (X) and the target variable (y):

# %%
X = data.drop('churn', axis=1)  # Features
y = data['churn']  # Target variable

# %% [markdown]
# # Convert categorical variables into numerical form using one-hot encoding (if necessary):

# %%
X_encoded = pd.get_dummies(X, columns=['state', 'international plan', 'voice mail plan'])

# %%
X_encoded = X_encoded.drop(columns='phone number')

# %% [markdown]
# # Split the data into training and testing sets:

# %%
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# %% [markdown]
# # Create an instance of the DecisionTreeClassifier and fit the model on the training data:

# %%
X_train
# Out:
#       account length  area code  number vmail messages  total day minutes  \
# 817              243        510                      0               95.5
# 1373             108        415                      0              112.0
# 679               75        415                      0              222.4
# 56               141        415                      0              126.9
# 1993              86        510                      0              216.3
# ...              ...        ...                    ...                ...
# 1095             106        510                      0              274.4
# 1130             122        415                      0               35.1
# 1294              66        408                      0               87.6
# 860              169        415                      0              179.2
# 3174              36        408                     43               29.9
#
#       total day calls  total day charge  total eve minutes  total eve calls  \
# 817                92             16.24              163.7               63
# 1373              105             19.04              193.7              110
# 679                78             37.81              327.0              111
# 56                 98             21.57              180.0               62
# 1993               96             36.77              266.3               77
# ...               ...               ...                ...              ...
# 1095              120             46.65              198.6               82
# 1130               62              5.97              180.8               89
# 1294               76             14.89              262.0              111
# 860               111             30.46              175.2              130
# 3174              123              5.08              129.1              117
#
#       total eve charge  total night minutes  ...  state_VA  state_VT  \
# 817              13.91                264.2  ...         0         0
# 1373             16.46                208.9  ...         0         0
# 679              27.80                208.0  ...         0         0
# 56               15.30                140.8  ...         0         0
# 1993             22.64                214.0  ...         0         0
# ...                ...                  ...  ...       ...       ...
# 1095             16.88                160.8  ...         0         0
# 1130             15.37                251.6  ...         0         0
# 1294             22.27                184.6  ...         0         0
# 860              14.89                228.6  ...         0         0
# 3174             10.97                325.9  ...         0         0
#
#       state_WA  state_WI  state_WV  state_WY  international plan_no  \
# 817          0         0         0         0                      1
# 1373         0         0         0         0                      1
# 679          0         0         0         0                      0
# 56           0         0         0         0                      1
# 1993         0         0         0         0                      1
# ...        ...       ...       ...       ...                    ...
# 1095         0         0         0         0                      1
# 1130         0         0         0         0                      1
# 1294         0         0         0         0                      1
# 860          0         0         0         0                      1
# 3174         0         0         0         0                      1
#
#       international plan_yes  voice mail plan_no  voice mail plan_yes
# 817                        0                   1                    0
# 1373                       0                   1                    0
# 679                        1                   1                    0
# 56                         0                   1                    0
# 1993                       0                   1                    0
# ...                      ...                 ...                  ...
# 1095                       0                   1                    0
# 1130                       0                   1                    0
# 1294                       0                   1                    0
# 860                        0                   1                    0
# 3174                       0                   0                    1
#
# [2666 rows x 71 columns]

# %%
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# # Make predictions on the test set:

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# # Evaluate the accuracy of the model:

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9325337331334332

# %%
plt.figure(figsize=(12, 8))
plot_tree(model, feature_names=X_encoded.columns, class_names=['False', 'True'], filled=True)
plt.show()

# %%
# Get feature importances
importances = model.feature_importances_

# Sort feature importances in descending order
indices = np.argsort(importances)[::-1]

# Create bar plot of feature importances
plt.figure(figsize=(10, 6))
plt.bar(range(X_encoded.shape[1]), importances[indices])
plt.xticks(range(X_encoded.shape[1]), X_encoded.columns[indices], rotation=90)
plt.xlabel("Feature")
plt.ylabel("Importance")
plt.title("Feature Importances")
plt.show()

# %%
def print_decision_rules(tree, feature_names, class_names, node_index=0, pad=""):
    left_child = tree.tree_.children_left[node_index]
    right_child = tree.tree_.children_right[node_index]

    if left_child == -1 and right_child == -1:
        # Leaf node reached
        class_label = class_names[np.argmax(tree.tree_.value[node_index])]

        print(pad + "Class:", class_label)
        return

    feature_index = tree.tree_.feature[node_index]
    threshold = tree.tree_.threshold[node_index]
    feature_name = feature_names[feature_index]

    print(pad + "if", feature_name, "<=", threshold, "then:")
    print_decision_rules(tree, feature_names, class_names, left_child, pad + "  ")

    print(pad + "if", feature_name, ">", threshold, "then:")
    print_decision_rules(tree, feature_names, class_names, right_child, pad + "  ")

# Display decision rules of the trained decision tree model
print_decision_rules(model, X_encoded.columns, ['False', 'True'])
# Out:
# if total day minutes <= 263.5500030517578 then:
#   if customer service calls <= 3.5 then:
#     if international plan_yes <= 0.5 then:
#       if total day minutes <= 223.25 then:
#         if total eve minutes <= 341.1499938964844 then:
#           if state_TX <= 0.5 then:
#             if state_DC <= 0.5 then:
#               if total night calls <= 104.5 then:
#                 if total night charge <= 15.910000324249268 then:
#                   if total day calls <= 124.5 then:
#                     if state_NC <= 0.5 then:
#                       if state_IN <= 0.5 then:
#                         if state_RI <= 0.5 then:
#                           if state_MN <= 0.5 then:
#                             if state_ME <= 0.5 then:
#                               if state_LA <= 0.5 then:
#                                 if state_UT <= 0.5 then:
#                                   Class: False
#                                 if state_UT > 0.5 then:
#                                   if total day charge <= 36.165000915527344 then:
#                                     Class: False
#                                   if total day charge > 36.165000915527344 then:
#                                     Class: True
#                               if state_LA > 0.5 then:
#                                 if total intl minutes <= 12.25 then:
#                                   Class: False
#                                 if total intl minutes > 12.25 then:
#                                   if number vmail messages <= 23.5 then:
#                                     Class: False
#                                   if number vmail messages > 23.5 then:
#                                     Class: True
#                             if state_ME > 0.5 then:
#                               if total night calls <= 73.5 then:
#                                 if total intl charge <= 2.5399999618530273 then:
#                                   Class: True
#                                 if total intl charge > 2.5399999618530273 then:
#                                   Class: False
#                               if total night calls > 73.5 then:
#                                 Class: False
#                           if state_MN > 0.5 then:
#                             if total night calls <= 102.0 then:
#                               Class: False
#                             if total night calls > 102.0 then:
#                               if area code <= 462.5 then:
#                                 Class: False
#                               if area code > 462.5 then:
#                                 Class: True
#                         if state_RI > 0.5 then:
#                           if total night calls <= 67.0 then:
#                             if total night charge <= 8.440000057220459 then:
#                               Class: True
#                             if total night charge > 8.440000057220459 then:
#                               Class: False
#                           if total night calls > 67.0 then:
#                             Class: False
#                       if state_IN > 0.5 then:
#                         if total day calls <= 118.5 then:
#                           Class: False
#                         if total day calls > 118.5 then:
#                           if total intl charge <= 2.740000009536743 then:
#                             Class: False
#                           if total intl charge > 2.740000009536743 then:
#                             Class: True
#                     if state_NC > 0.5 then:
#                       if account length <= 60.5 then:
#                         if number vmail messages <= 19.0 then:
#                           Class: True
#                         if number vmail messages > 19.0 then:
#                           Class: False
#                       if account length > 60.5 then:
#                         Class: False
#                   if total day calls > 124.5 then:
#                     if state_MS <= 0.5 then:
#                       if number vmail messages <= 40.5 then:
#                         if state_SC <= 0.5 then:
#                           if total eve charge <= 6.634999990463257 then:
#                             if customer service calls <= 2.0 then:
#                               Class: False
#                             if customer service calls > 2.0 then:
#                               Class: True
#                           if total eve charge > 6.634999990463257 then:
#                             if number vmail messages <= 34.0 then:
#                               if state_OH <= 0.5 then:
#                                 Class: False
#                               if state_OH > 0.5 then:
#                                 if total night charge <= 7.900000095367432 then:
#                                   if total day calls <= 128.5 then:
#                                     Class: False
#                                   if total day calls > 128.5 then:
#                                     Class: True
#                                 if total night charge > 7.900000095367432 then:
#                                   Class: False
#                             if number vmail messages > 34.0 then:
#                               if state_MT <= 0.5 then:
#                                 Class: False
#                               if state_MT > 0.5 then:
#                                 Class: True
#                         if state_SC > 0.5 then:
#                           if total intl minutes <= 11.650000095367432 then:
#                             Class: False
#                           if total intl minutes > 11.650000095367432 then:
#                             Class: True
#                       if number vmail messages > 40.5 then:
#                         Class: True
#                     if state_MS > 0.5 then:
#                       Class: True
#                 if total night charge > 15.910000324249268 then:
#                   if total night charge <= 16.87000036239624 then:
#                     Class: True
#                   if total night charge > 16.87000036239624 then:
#                     Class: False
#               if total night calls > 104.5 then:
#                 if account length <= 152.5 then:
#                   if number vmail messages <= 46.5 then:
#                     if total night minutes <= 239.1999969482422 then:
#                       if state_CA <= 0.5 then:
#                         if state_PA <= 0.5 then:
#                           if total eve calls <= 132.5 then:
#                             if state_NM <= 0.5 then:
#                               if state_AZ <= 0.5 then:
#                                 if state_WA <= 0.5 then:
#                                   Class: False
#                                 if state_WA > 0.5 then:
#                                   if total intl charge <= 2.0399999618530273 then:
#                                     Class: True
#                                   if total intl charge > 2.0399999618530273 then:
#                                     Class: False
#                               if state_AZ > 0.5 then:
#                                 if total eve calls <= 76.0 then:
#                                   Class: True
#                                 if total eve calls > 76.0 then:
#                                   Class: False
#                             if state_NM > 0.5 then:
#                               if number vmail messages <= 30.5 then:
#                                 Class: False
#                               if number vmail messages > 30.5 then:
#                                 Class: True
#                           if total eve calls > 132.5 then:
#                             if state_MT <= 0.5 then:
#                               if state_SC <= 0.5 then:
#                                 Class: False
#                               if state_SC > 0.5 then:
#                                 Class: True
#                             if state_MT > 0.5 then:
#                               Class: True
#                         if state_PA > 0.5 then:
#                           if voice mail plan_no <= 0.5 then:
#                             Class: True
#                           if voice mail plan_no > 0.5 then:
#                             Class: False
#                       if state_CA > 0.5 then:
#                         if total eve calls <= 89.5 then:
#                           Class: True
#                         if total eve calls > 89.5 then:
#                           Class: False
#                     if total night minutes > 239.1999969482422 then:
#                       if total night minutes <= 239.5999984741211 then:
#                         Class: True
#                       if total night minutes > 239.5999984741211 then:
#                         if state_MS <= 0.5 then:
#                           if total day charge <= 37.76500129699707 then:
#                             if state_ME <= 0.5 then:
#                               if total day calls <= 64.0 then:
#                                 if total day calls <= 60.5 then:
#                                   Class: False
#                                 if total day calls > 60.5 then:
#                                   if total night minutes <= 268.0500030517578 then:
#                                     Class: True
#                                   if total night minutes > 268.0500030517578 then:
#                                     Class: False
#                               if total day calls > 64.0 then:
#                                 if state_MT <= 0.5 then:
#                                   if state_NE <= 0.5 then:
#                                     if state_OH <= 0.5 then:
#                                       Class: False
#                                     if state_OH > 0.5 then:
#                                       if total intl minutes <= 10.800000190734863 then:
#                                         Class: False
#                                       if total intl minutes > 10.800000190734863 then:
#                                         if total night minutes <= 249.0 then:
#                                           Class: True
#                                         if total night minutes > 249.0 then:
#                                           Class: False
#                                   if state_NE > 0.5 then:
#                                     if total day minutes <= 174.10000610351562 then:
#                                       Class: False
#                                     if total day minutes > 174.10000610351562 then:
#                                       Class: True
#                                 if state_MT > 0.5 then:
#                                   if total intl minutes <= 11.200000286102295 then:
#                                     Class: True
#                                   if total intl minutes > 11.200000286102295 then:
#                                     Class: False
#                             if state_ME > 0.5 then:
#                               if total eve minutes <= 202.75 then:
#                                 Class: True
#                               if total eve minutes > 202.75 then:
#                                 Class: False
#                           if total day charge > 37.76500129699707 then:
#                             if number vmail messages <= 4.0 then:
#                               Class: True
#                             if number vmail messages > 4.0 then:
#                               Class: False
#                         if state_MS > 0.5 then:
#                           Class: True
#                   if number vmail messages > 46.5 then:
#                     if state_SD <= 0.5 then:
#                       Class: False
#                     if state_SD > 0.5 then:
#                       Class: True
#                 if account length > 152.5 then:
#                   if total day calls <= 143.5 then:
#                     if account length <= 159.5 then:
#                       if total eve calls <= 90.5 then:
#                         if total day charge <= 30.600000381469727 then:
#                           Class: True
#                         if total day charge > 30.600000381469727 then:
#                           Class: False
#                       if total eve calls > 90.5 then:
#                         if total eve calls <= 146.5 then:
#                           if state_LA <= 0.5 then:
#                             Class: False
#                           if state_LA > 0.5 then:
#                             if total night calls <= 124.5 then:
#                               Class: True
#                             if total night calls > 124.5 then:
#                               Class: False
#                         if total eve calls > 146.5 then:
#                           Class: True
#                     if account length > 159.5 then:
#                       if state_ID <= 0.5 then:
#                         Class: False
#                       if state_ID > 0.5 then:
#                         if total night charge <= 9.610000133514404 then:
#                           Class: True
#                         if total night charge > 9.610000133514404 then:
#                           Class: False
#                   if total day calls > 143.5 then:
#                     Class: True
#             if state_DC > 0.5 then:
#               if total eve calls <= 91.5 then:
#                 if account length <= 94.5 then:
#                   Class: True
#                 if account length > 94.5 then:
#                   Class: False
#               if total eve calls > 91.5 then:
#                 Class: False
#           if state_TX > 0.5 then:
#             if total day charge <= 35.19000053405762 then:
#               if total day calls <= 84.5 then:
#                 if voice mail plan_yes <= 0.5 then:
#                   Class: True
#                 if voice mail plan_yes > 0.5 then:
#                   Class: False
#               if total day calls > 84.5 then:
#                 Class: False
#             if total day charge > 35.19000053405762 then:
#               if total eve calls <= 85.5 then:
#                 Class: True
#               if total eve calls > 85.5 then:
#                 Class: False
#         if total eve minutes > 341.1499938964844 then:
#           if total night charge <= 10.389999866485596 then:
#             Class: False
#           if total night charge > 10.389999866485596 then:
#             Class: True
#       if total day minutes > 223.25 then:
#         if total eve minutes <= 266.6999969482422 then:
#           if total night minutes <= 201.9000015258789 then:
#             if account length <= 25.0 then:
#               if area code <= 462.5 then:
#                 Class: False
#               if area code > 462.5 then:
#                 Class: True
#             if account length > 25.0 then:
#               if state_CT <= 0.5 then:
#                 if state_MA <= 0.5 then:
#                   if state_OR <= 0.5 then:
#                     if state_NJ <= 0.5 then:
#                       Class: False
#                     if state_NJ > 0.5 then:
#                       if total night minutes <= 174.45000457763672 then:
#                         Class: False
#                       if total night minutes > 174.45000457763672 then:
#                         Class: True
#                   if state_OR > 0.5 then:
#                     if customer service calls <= 0.5 then:
#                       Class: True
#                     if customer service calls > 0.5 then:
#                       Class: False
#                 if state_MA > 0.5 then:
#                   if area code <= 411.5 then:
#                     Class: True
#                   if area code > 411.5 then:
#                     Class: False
#               if state_CT > 0.5 then:
#                 if total eve charge <= 13.179999828338623 then:
#                   Class: True
#                 if total eve charge > 13.179999828338623 then:
#                   Class: False
#           if total night minutes > 201.9000015258789 then:
#             if total day charge <= 41.665000915527344 then:
#               if total night minutes <= 205.39999389648438 then:
#                 if total eve minutes <= 163.9000015258789 then:
#                   Class: False
#                 if total eve minutes > 163.9000015258789 then:
#                   Class: True
#               if total night minutes > 205.39999389648438 then:
#                 if state_FL <= 0.5 then:
#                   if state_NJ <= 0.5 then:
#                     if state_NY <= 0.5 then:
#                       if state_MD <= 0.5 then:
#                         if state_OR <= 0.5 then:
#                           Class: False
#                         if state_OR > 0.5 then:
#                           if total day calls <= 92.5 then:
#                             Class: True
#                           if total day calls > 92.5 then:
#                             Class: False
#                       if state_MD > 0.5 then:
#                         if total day calls <= 91.5 then:
#                           Class: True
#                         if total day calls > 91.5 then:
#                           Class: False
#                     if state_NY > 0.5 then:
#                       if total night charge <= 11.110000133514404 then:
#                         Class: True
#                       if total night charge > 11.110000133514404 then:
#                         Class: False
#                   if state_NJ > 0.5 then:
#                     if total intl charge <= 3.0649999380111694 then:
#                       Class: False
#                     if total intl charge > 3.0649999380111694 then:
#                       Class: True
#                 if state_FL > 0.5 then:
#                   Class: True
#             if total day charge > 41.665000915527344 then:
#               if total eve charge <= 17.010000228881836 then:
#                 if total night minutes <= 290.5500030517578 then:
#                   Class: False
#                 if total night minutes > 290.5500030517578 then:
#                   Class: True
#               if total eve charge > 17.010000228881836 then:
#                 if voice mail plan_yes <= 0.5 then:
#                   if state_MT <= 0.5 then:
#                     Class: True
#                   if state_MT > 0.5 then:
#                     Class: False
#                 if voice mail plan_yes > 0.5 then:
#                   Class: False
#         if total eve minutes > 266.6999969482422 then:
#           if voice mail plan_no <= 0.5 then:
#             Class: False
#           if voice mail plan_no > 0.5 then:
#             if state_HI <= 0.5 then:
#               Class: True
#             if state_HI > 0.5 then:
#               Class: False
#     if international plan_yes > 0.5 then:
#       if total intl calls <= 2.5 then:
#         Class: True
#       if total intl calls > 2.5 then:
#         if total intl charge <= 3.534999966621399 then:
#           if total eve minutes <= 324.8500061035156 then:
#             if total day minutes <= 251.9000015258789 then:
#               if total night minutes <= 84.4000015258789 then:
#                 Class: True
#               if total night minutes > 84.4000015258789 then:
#                 Class: False
#             if total day minutes > 251.9000015258789 then:
#               if total eve minutes <= 241.1500015258789 then:
#                 if total day charge <= 43.045000076293945 then:
#                   Class: True
#                 if total day charge > 43.045000076293945 then:
#                   Class: False
#               if total eve minutes > 241.1500015258789 then:
#                 Class: True
#           if total eve minutes > 324.8500061035156 then:
#             if total intl charge <= 3.159999966621399 then:
#               Class: True
#             if total intl charge > 3.159999966621399 then:
#               Class: False
#         if total intl charge > 3.534999966621399 then:
#           Class: True
#   if customer service calls > 3.5 then:
#     if total day charge <= 29.5049991607666 then:
#       if total eve minutes <= 211.9000015258789 then:
#         if state_IL <= 0.5 then:
#           if state_AL <= 0.5 then:
#             if state_CO <= 0.5 then:
#               Class: True
#             if state_CO > 0.5 then:
#               if voice mail plan_no <= 0.5 then:
#                 Class: False
#               if voice mail plan_no > 0.5 then:
#                 Class: True
#           if state_AL > 0.5 then:
#             Class: False
#         if state_IL > 0.5 then:
#           Class: False
#       if total eve minutes > 211.9000015258789 then:
#         if total day charge <= 25.77999973297119 then:
#           if total intl calls <= 6.5 then:
#             Class: True
#           if total intl calls > 6.5 then:
#             if total day charge <= 21.369999885559082 then:
#               Class: True
#             if total day charge > 21.369999885559082 then:
#               Class: False
#         if total day charge > 25.77999973297119 then:
#           Class: False
#     if total day charge > 29.5049991607666 then:
#       if total eve charge <= 11.484999656677246 then:
#         if total day minutes <= 236.95000457763672 then:
#           if total intl calls <= 5.5 then:
#             Class: True
#           if total intl calls > 5.5 then:
#             Class: False
#         if total day minutes > 236.95000457763672 then:
#           Class: False
#       if total eve charge > 11.484999656677246 then:
#         if total intl minutes <= 13.700000286102295 then:
#           if state_MS <= 0.5 then:
#             if state_MN <= 0.5 then:
#               if state_WY <= 0.5 then:
#                 if state_NH <= 0.5 then:
#                   Class: False
#                 if state_NH > 0.5 then:
#                   if total intl charge <= 2.674999952316284 then:
#                     Class: False
#                   if total intl charge > 2.674999952316284 then:
#                     Class: True
#               if state_WY > 0.5 then:
#                 if total day calls <= 85.0 then:
#                   Class: False
#                 if total day calls > 85.0 then:
#                   Class: True
#             if state_MN > 0.5 then:
#               if total day minutes <= 185.0 then:
#                 Class: True
#               if total day minutes > 185.0 then:
#                 Class: False
#           if state_MS > 0.5 then:
#             Class: True
#         if total intl minutes > 13.700000286102295 then:
#           if international plan_yes <= 0.5 then:
#             if total eve minutes <= 172.9000015258789 then:
#               if total day charge <= 31.3700008392334 then:
#                 Class: True
#               if total day charge > 31.3700008392334 then:
#                 Class: False
#             if total eve minutes > 172.9000015258789 then:
#               Class: False
#           if international plan_yes > 0.5 then:
#             Class: True
# if total day minutes > 263.5500030517578 then:
#   if voice mail plan_no <= 0.5 then:
#     if international plan_no <= 0.5 then:
#       if total day charge <= 47.60499954223633 then:
#         Class: True
#       if total day charge > 47.60499954223633 then:
#         if area code <= 462.5 then:
#           Class: False
#         if area code > 462.5 then:
#           Class: True
#     if international plan_no > 0.5 then:
#       Class: False
#   if voice mail plan_no > 0.5 then:
#     if total eve charge <= 15.695000171661377 then:
#       if total day minutes <= 301.8000030517578 then:
#         if total night charge <= 9.570000171661377 then:
#           if account length <= 164.5 then:
#             Class: False
#           if account length > 164.5 then:
#             Class: True
#         if total night charge > 9.570000171661377 then:
#           if total day charge <= 46.94499969482422 then:
#             if total eve calls <= 128.5 then:
#               Class: False
#             if total eve calls > 128.5 then:
#               if total day charge <= 46.09000015258789 then:
#                 Class: True
#               if total day charge > 46.09000015258789 then:
#                 Class: False
#           if total day charge > 46.94499969482422 then:
#             Class: True
#       if total day minutes > 301.8000030517578 then:
#         if total eve minutes <= 97.94999694824219 then:
#           Class: False
#         if total eve minutes > 97.94999694824219 then:
#           Class: True
#     if total eve charge > 15.695000171661377 then:
#       if total night minutes <= 114.5 then:
#         if total eve charge <= 21.625 then:
#           Class: False
#         if total eve charge > 21.625 then:
#           Class: True
#       if total night minutes > 114.5 then:
#         if total day calls <= 147.5 then:
#           if total night charge <= 5.7149999141693115 then:
#             if account length <= 108.0 then:
#               Class: False
#             if account length > 108.0 then:
#               Class: True
#           if total night charge > 5.7149999141693115 then:
#             if state_ID <= 0.5 then:
#               Class: True
#             if state_ID > 0.5 then:
#               if total night minutes <= 178.0500030517578 then:
#                 Class: False
#               if total night minutes > 178.0500030517578 then:
#                 Class: True
#         if total day calls > 147.5 then:
#           Class: False

# %%
from sklearn.metrics import classification_report, confusion_matrix

# Evaluate the model's performance
print("Classification Report:")
print(classification_report(y_test, y_pred))

# Generate a confusion matrix
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.95      0.97      0.96       566
#         True       0.80      0.73      0.77       101
#
#     accuracy                           0.93       667
#    macro avg       0.88      0.85      0.86       667
# weighted avg       0.93      0.93      0.93       667
#
# Confusion Matrix:
# [[548  18]
#  [ 27  74]]
